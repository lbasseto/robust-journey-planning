# %%
import folium
import pandas as pd
from datetime import datetime, date, timedelta
from folium.plugins import HeatMap

# %%
stations = pd.read_csv('data/filtered_stations.csv')
stations = stations.set_index('Remark')
stations = stations.drop(['Unnamed: 0'], axis = 1)

#stations.to_pickle('stations.pkl')

# %%
res = {'departure_time': '19:09:00',
 'arrival_time': '19:51:00',
 'duration': '00:42:00',
 'probability': 0.9997405493724597,
 'path': [{'src': 'Kilchberg',
   'dst': 'Zürich HB',
   'type': 'Zug',
   'line': 'S8',
   'departure_time': '19:09:00',
   'arrival_time': '19:23:00'},
  {'src': 'Zürich HB',
   'dst': 'Glanzenberg',
   'type': 'Zug',
   'line': 'S3',
   'departure_time': '19:29:00',
   'arrival_time': '19:40:00'},
  {'src': 'Glanzenberg',
   'dst': 'Urdorf, Schlierenstrasse',
   'type': 'walk',
   'departure_time': '19:40:00',
   'arrival_time': '19:51:00'}]}

# %%
heatmap_data = {'Kilchberg': 2500.0,
 'Zürich HB': 916.6666666666666,
 'Zürich Hardbrücke': 333.3333333333333,
 'Zürich Hardbrücke, Bahnhof': 250.0,
 'Zürich Stadelhofen': 666.6666666666666,
 'Zürich Tiefenbrunnen': 83.33333333333333,
 'Zürich Stadelhofen FB': 583.3333333333333,
 'Zürich Kreuzplatz': 166.66666666666666,
 'Zürich, Bellevue': 333.3333333333333,
 'Zürich, Opernhaus': 500.0,
 'Zürich, Kreuzstrasse': 250.0,
 'Zürich, Helmhaus': 83.33333333333333,
 'Zürich, Hottingerplatz': 83.33333333333333,
 'Zürich, Kunsthaus': 166.66666666666666,
 'Zürich, Sprecherstrasse': 333.3333333333333,
 'Zürich Oerlikon': 166.66666666666666,
 'Zürich Oerlikon, Bahnhof': 83.33333333333333,
 'Zürich Altstetten': 416.66666666666663,
 'Zürich Altstetten, Bahnhof': 333.3333333333333,
 'Zürich Altstetten, Bahnhof N': 250.0,
 'Zürich, Baslerstrasse': 83.33333333333333,
 'Zürich, Bristenstrasse': 166.66666666666666,
 'Zürich, Würzgraben': 83.33333333333333,
 'Zürich HB SZU': 750.0,
 'Zürich Landesmuseum (See)': 750.0,
 'Zürich Storchen': 83.33333333333333,
 'Zürich Central (Polybahn)': 500.0,
 'Zürich Polyterrasse': 416.66666666666663,
 'Hochschulen': 416.66666666666663,
 'Zürich Limmatquai': 333.3333333333333,
 'Zürich, Bahnhofplatz/HB': 750.0,
 'Zürich, Bahnhofquai/HB': 750.0,
 'Zürich, Central': 583.3333333333333,
 'Zürich, Bahnhofstrasse/HB': 666.6666666666666,
 'Zürich, Beckenhof': 250.0,
 'Zürich, ETH/Universitätsspital': 166.66666666666666,
 'Zürich, Haldenbach': 250.0,
 'Zürich, Haldenegg': 500.0,
 'Zürich, Löwenplatz': 583.3333333333333,
 'Zürich, Museum für Gestaltung': 250.0,
 'Zürich, Neumarkt': 83.33333333333333,
 'Zürich, Neumühlequai/HB': 666.6666666666666,
 'Zürich, Ottikerstrasse': 83.33333333333333,
 'Zürich, Rathaus': 166.66666666666666,
 'Zürich, Rennweg': 333.3333333333333,
 'Zürich, Rudolf-Brun-Brücke': 416.66666666666663,
 'Zürich, Sihlpost/HB': 333.3333333333333,
 'Zürich, Sihlquai/HB': 583.3333333333333,
 'Zürich, Sonneggstrasse': 333.3333333333333,
 'Zürich, Stampfenbachplatz': 583.3333333333333,
 'Zürich, Winkelriedstrasse': 83.33333333333333,
 'Zürich Wiedikon': 1333.3333333333333,
 'Zürich, Goldbrunnenplatz': 583.3333333333333,
 'Zürich Selnau': 666.6666666666666,
 'Zürich Wiedikon, Bahnhof': 1250.0,
 'Zürich, Bäckeranlage': 500.0,
 'Zürich Selnau, Bahnhof': 666.6666666666666,
 'Zürich, Bertastrasse': 500.0,
 'Zürich, Bezirksgebäude': 916.6666666666666,
 'Zürich, Helvetiaplatz': 750.0,
 'Zürich,Kalkbreite/Bhf.Wiedikon': 916.6666666666666,
 'Zürich, Kanonengasse': 333.3333333333333,
 'Zürich, Kernstrasse': 916.6666666666666,
 'Zürich, Lochergut': 666.6666666666666,
 'Zürich, Militär-/Langstrasse': 333.3333333333333,
 'Zürich, Schmiede Wiedikon': 916.6666666666666,
 'Zürich, Sihlstrasse': 416.66666666666663,
 'Zürich, Stauffacher': 833.3333333333333,
 'Zürich, Werd': 1000.0,
 'Zürich, Zwinglihaus': 750.0,
 'Zürich, Zypressenstrasse': 333.3333333333333,
 'Zürich Wollishofen': 1666.6666666666665,
 'Zimmerberg-Basistunnel': 666.6666666666666,
 'Zürich Brunau': 833.3333333333333,
 'Zürich Saalsporthalle': 416.66666666666663,
 'Zürich, Saalsporthalle': 250.0,
 'Zürich, Sihlcity': 416.66666666666663,
 'Zürich Manegg': 166.66666666666666,
 'Zürich Wollishofen (See)': 1333.3333333333333,
 'Zürich, Rote Fabrik': 1083.3333333333333,
 'Zürich, Besenrainstrasse': 1166.6666666666665,
 'Zürich Wollishofen, Bhf (Bus)': 1583.3333333333333,
 'Zürich Wollishofen, Bhf (Tram)': 1583.3333333333333,
 'Zürich, Billoweg': 1166.6666666666665,
 'Zürich, Brunau/Mutschellenstr.': 666.6666666666666,
 'Zürich, Brunaustrasse': 666.6666666666666,
 'Zürich, Butzenstrasse': 916.6666666666666,
 'Zürich, Jugendherberge': 1250.0,
 'Zürich, Kalchbühlweg': 1000.0,
 'Zürich, Landiwiese': 1250.0,
 'Zürich, Morgental': 1166.6666666666665,
 'Zürich, Post Wollishofen': 1250.0,
 'Zürich, Sukkulentensammlung': 750.0,
 'Zürich, Thujastrasse': 1083.3333333333333,
 'Zürich, Verenastrasse': 666.6666666666666,
 'Zürich Enge': 1416.6666666666665,
 'Zürich Binz': 416.66666666666663,
 'Zürich Giesshübel': 666.6666666666666,
 'Zürich Enge (See)': 666.6666666666666,
 'Zürich Bürkliplatz (See)': 583.3333333333333,
 'Zürich Enge, Bahnhof': 1333.3333333333333,
 'Zürich Enge, Bahnhof/Bederstr.': 1333.3333333333333,
 'Zürich, Börsenstrasse': 583.3333333333333,
 'Zürich, Brandschenkestrasse': 750.0,
 'Zürich, Bürkliplatz': 583.3333333333333,
 'Zürich, Hügelstrasse': 666.6666666666666,
 'Zürich, Hürlimannplatz': 1000.0,
 'Zürich, Manesseplatz': 666.6666666666666,
 'Zürich, Museum Rietberg': 1000.0,
 'Zürich, Paradeplatz': 500.0,
 'Zürich, Rentenanstalt': 1083.3333333333333,
 'Zürich, Schweizer Rück': 750.0,
 'Zürich, Sihlcity Nord': 666.6666666666666,
 'Zürich, Stockerstrasse': 833.3333333333333,
 'Zürich, Tunnelstrasse': 1083.3333333333333,
 'Zürich, Waffenplatz-/Bederstr.': 916.6666666666666,
 'Zürich, Waffenplatzstrasse': 916.6666666666666,
 'Zürich, Binz': 416.66666666666663,
 'Thalwil': 916.6666666666666,
 'Thalwil (See)': 583.3333333333333,
 'Thalwil, Feldstrasse': 166.66666666666666,
 'Thalwil, Mühlebachplatz': 333.3333333333333,
 'Thalwil, Zentrum': 750.0,
 'Thalwil, Bahnhof': 833.3333333333333,
 'Thalwil, Aegertli': 500.0,
 'Thalwil, Archstrasse': 666.6666666666666,
 'Thalwil, In Reben': 333.3333333333333,
 'Thalwil, Pilgerweg': 500.0,
 'Thalwil, Platte': 166.66666666666666,
 'Thalwil, Post': 666.6666666666666,
 'Thalwil, Rudishaldenstrasse': 333.3333333333333,
 'Thalwil, Seehaldenstrasse': 83.33333333333333,
 'Thalwil, Trotte': 333.3333333333333,
 'Thalwil, Zehntenstrasse': 83.33333333333333,
 'Thalwil, Sonnenberg': 166.66666666666666,
 'Rüschlikon': 1166.6666666666665,
 'Rüschlikon (See)': 750.0,
 'Rüschlikon, Bahnhof': 1000.0,
 'Rüschlikon, Belvoir': 666.6666666666666,
 'Rüschlikon, Bodengasse': 750.0,
 'Rüschlikon, Eggrain': 250.0,
 'Rüschlikon, Langhaldenstrasse': 833.3333333333333,
 'Rüschlikon, Loorain': 166.66666666666666,
 'Rüschlikon, Moosstrasse': 250.0,
 'Rüschlikon, Park im Grüene': 250.0,
 'Rüschlikon, Rebsteig': 416.66666666666663,
 'Rüschlikon, Säumerstrasse': 416.66666666666663,
 'Rüschlikon, Schlossstrasse': 416.66666666666663,
 'Rüschlikon, Weidstrasse': 916.6666666666666,
 'Thalwil, Park im Grüene': 166.66666666666666,
 'Zürich Wipkingen': 166.66666666666666,
 'Zürich Wipkingen, Bahnhof': 83.33333333333333,
 'Kilchberg ZH (See)': 2083.333333333333,
 'Kilchberg ZH, Altersheim': 1750.0,
 'Kilchberg ZH, Auf Brunnen': 1833.3333333333333,
 'Kilchberg ZH, Bächlerstrasse': 1666.6666666666665,
 'Kilchberg ZH, Bahnhof': 2416.6666666666665,
 'Kilchberg ZH, Bendlikon': 2166.6666666666665,
 'Kilchberg ZH, Gottlieb-Binder': 2000.0,
 'Kilchberg ZH, Hallenbad': 1500.0,
 'Kilchberg ZH, Hornhaldenstr.': 1500.0,
 'Kilchberg ZH, Kirche': 1583.3333333333333,
 'Kilchberg ZH, Spital': 1500.0,
 'Kilchberg ZH, Kreuzstrasse': 2250.0,
 'Kilchberg ZH, Lindt & Sprüngli': 1833.3333333333333,
 'Kilchberg ZH, Mythenstrasse': 1833.3333333333333,
 'Kilchberg ZH, Paradiessteig': 1750.0,
 'Kilchberg ZH, Paradiesstrasse': 2000.0,
 'Kilchberg ZH, Sanatorium': 2083.333333333333,
 'Kilchberg ZH, Schlimbergstr.': 2083.333333333333,
 'Kilchberg ZH, Schooren': 1583.3333333333333,
 'Kilchberg ZH, Schoorenstrasse': 1666.6666666666665,
 'Kilchberg ZH,Schulhaus Dorfstr': 2166.6666666666665,
 'Kilchberg ZH, Schwelle': 2083.333333333333,
 'Kilchberg ZH, Stockengut': 1916.6666666666665,
 'Kilchberg ZH, Weinbergstrasse': 1583.3333333333333,
 'Kilchberg ZH, Breitloo': 1750.0,
 'Kilchberg ZH, Emilienheim': 1583.3333333333333}

# %%
def get_description(node):
    prefix = ''
    if node['type'] == 'walk':
        prefix = 'Walk: '
    else:
        prefix = node['type'] + ' ' + node['line'] + ': '
    return prefix + node['departure_time'] + ' ' + node['src'] + ' -> ' + node['arrival_time'] + ' ' + node['dst']

# %%
def get_map_with_plot(res, heatmap_data = None):
    m = zurich_map = folium.Map(location=[47.376846, 8.543938],
     zoom_control = False, min_zoom=11, max_zoom=11, zoom_start=11,
      tiles="cartodbpositron", width='75%', height='75%')
    
    #stations = pd.read_pickle("../resources/stations.pkl")
    
    if heatmap_data != None:
        heatmap_list = []
        max_reachable_dist = 0
        for key, value in heatmap_data.items():
            station = stations.loc[key]
            
            folium.Circle(
              location=[station['Latitude'], station['Longitude']],
              radius=value,
              color='green',
              fill=True,
              fill_color='green',
              fill_opacity=0.07,
              weight=0.1
           ).add_to(m)
    
    trip = res['path']
    for idx, node in enumerate(trip):
        src_station = stations.loc[node['src']]
        src_pos = (src_station['Latitude'], src_station['Longitude'])
        dst_station = stations.loc[node['dst']]
        dst_pos = (dst_station['Latitude'], dst_station['Longitude'])

        description = get_description(node)

        if idx == 0:
            # Start station
            folium.vector_layers.Marker(src_pos, popup=description, tooltip=src_station.name, icon=folium.Icon(color='green')).add_to(m)
        else:
            folium.vector_layers.Marker(src_pos, popup=description, tooltip=src_station.name).add_to(m)

        folium.PolyLine([src_pos, dst_pos], color="blue", weight=2.5, opacity=1).add_to(m)

        if idx == (len(trip) - 1):
            # Plot arrival point
            folium.vector_layers.Marker(dst_pos, popup=None, tooltip=dst_station.name, icon=folium.Icon(color='red')).add_to(m)

    return m

# %%
get_map_with_plot(res, heatmap_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
zurich_map.save('zurich_map_blank.html')
