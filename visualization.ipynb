# %%
import folium
import pandas as pd

# %%
stations = pd.read_csv('data/filtered_stations.csv')
stations = stations.set_index('Remark')
stations = stations.drop(['Unnamed: 0'], axis = 1)

stations.to_pickle('stations.pkl')

# %%
station_list = stations.index.tolist()
station_list.sort()
print(station_list)
# Out:
# ['Adlikon b. R., Dorf', 'Adlikon b. R., Pächterried', 'Adliswil', 'Adliswil (Luftseilbahnstation)', 'Adliswil, Ahornweg', 'Adliswil, Badstrasse', 'Adliswil, Bahnhof', 'Adliswil, Baldernstrasse', 'Adliswil, Baumgartenweg', 'Adliswil, Bodenacker', 'Adliswil, Büchel', 'Adliswil, Eichenweg', 'Adliswil, Feldblumenstrasse', 'Adliswil, Friedhof', 'Adliswil, Grundstrasse', 'Adliswil, Grüt', 'Adliswil, Hofackerstrasse', 'Adliswil, Krone', 'Adliswil, Landolt-Junker-Str.', 'Adliswil, Moos', 'Adliswil, Poststrasse', 'Adliswil, Rifertstrasse', 'Adliswil, Rütistrasse/Wacht', 'Adliswil, Schulhaus Kopfholz', 'Adliswil, Tiefacker', 'Adliswil, Tobelhof', 'Adliswil, Wanneten-/Haldenstr.', 'Adliswil, Zopf', 'Aesch ZH, Gemeindehaus', 'Aesch ZH, Heligenmattstrasse', 'Aesch bei Maur, Im Brünneli', 'Baltenswil', 'Bassersdorf', 'Bassersdorf, Bahnhof', 'Bassersdorf, Bächli', 'Bassersdorf, Chlupfgasse', 'Bassersdorf, Dietlikonerstr.', 'Bassersdorf, Gemeindehaus', 'Bassersdorf, Löwen', 'Bassersdorf, Schmitte', 'Bassersdorf, Sportanlage', 'Bassersdorf, Talgüetli', 'Benglen, Bodenacher', 'Benglen, Gerlisbrunnen', 'Benglen, Langwis', 'Binz bei Maur, Bautacher', 'Binz bei Maur, Fridlimatt', 'Binz bei Maur, Post', 'Birmensdorf ZH', 'Birmensdorf ZH, Aescherstrasse', 'Birmensdorf ZH, Altenberg', 'Birmensdorf ZH, Bahnhof', 'Birmensdorf ZH, Bahnhof Süd', 'Birmensdorf ZH, Landikon Bach', 'Birmensdorf ZH, Landikon Dorf', 'Birmensdorf ZH, Obere Risi', 'Birmensdorf ZH, Ristet', 'Birmensdorf ZH, Sternen/WSL', 'Birmensdorf ZH, Untere Risi', 'Birmensdorf ZH, Weissenbrunnen', 'Birmensdorf ZH, Zentrum', 'Bonstetten, Chrüzacher', 'Bonstetten, Dorfplatz', 'Bonstetten, Dorfstrasse', 'Bonstetten, Isenbach', 'Bonstetten, Lärchenhof', 'Bonstetten, Lätten', 'Bonstetten, Sunnenberg', 'Bonstetten-Wettswil', 'Bonstetten-Wettswil, Bahnhof', 'Brüttisellen, Gsellhof', 'Brüttisellen, Haldenbrücke', 'Brüttisellen, Neuwisen', 'Brüttisellen, Ob. Wangenstr.', 'Brüttisellen, Zentrum', 'Dietikon, Birmensdorferstrasse', 'Dietikon, Schönenwerd', 'Dietlikon', 'Dietlikon, Aegert', 'Dietlikon, Bahnhof', 'Dietlikon, Bahnhof/Bad', 'Dietlikon, Brandbachstrasse', 'Dietlikon, Dornenstrasse', 'Dietlikon, Dübendorferstrasse', 'Dietlikon, Fuchshalde', 'Dietlikon, Hinentalstrasse', 'Dietlikon, Hofwiesen', 'Dietlikon, Hörnligraben', 'Dietlikon, In Lampitzäckern', 'Dietlikon, Industriestrasse', 'Dietlikon, Klimmweg', 'Dietlikon, Lettenstrasse', 'Dietlikon, Lindenstrasse', 'Dietlikon, Pünten', 'Dietlikon, Rebackerweg', 'Dietlikon, Riedenerstrasse', 'Dietlikon, Zentrum', 'Dübendorf', 'Dübendorf, Alterszentrum', 'Dübendorf, Bahnhof', 'Dübendorf, Bahnhof Nord', 'Dübendorf, Bauhof', 'Dübendorf, Bettlistrasse', 'Dübendorf, Branzenäsch', 'Dübendorf, Breitibach', 'Dübendorf, Chriesmatt', 'Dübendorf, City Center', 'Dübendorf, Claridenstrasse', 'Dübendorf, EMPA', 'Dübendorf, Eglishölzli', 'Dübendorf, Flugplatz', 'Dübendorf, Gfenn', 'Dübendorf, Giessen', 'Dübendorf, Glärnischstrasse', 'Dübendorf, Grüzenstrasse', 'Dübendorf, Heidenrietstrasse', 'Dübendorf, Hochbord', 'Dübendorf, Hochbord Süd', 'Dübendorf, Hoffnung', 'Dübendorf, Högler', 'Dübendorf, Im Grund', 'Dübendorf, Kirche Wil', 'Dübendorf, Kreuzbühl', 'Dübendorf, Kunsteisbahn', 'Dübendorf, Kämmaten', 'Dübendorf, Lindenbühl', 'Dübendorf, Lindenplatz', 'Dübendorf, Meiershofstrasse', 'Dübendorf, Memphis', 'Dübendorf, Neugut Süd', 'Dübendorf, Post', 'Dübendorf, Raubbühl', 'Dübendorf, Ringstrasse', 'Dübendorf, Ringwiesen', 'Dübendorf, Schossacher', 'Dübendorf, Schwimmbad', 'Dübendorf, Sonnenberg', 'Dübendorf, Sonnental', 'Dübendorf, Sport Heerenschürli', 'Dübendorf, Stadthaus', 'Dübendorf, Sunnhalde', 'Dübendorf, Unterdorf', 'Dübendorf, Wasserfurren', 'Dübendorf, Zelglistrasse', 'Dübendorf, Zwinggarten', 'Ebmatingen, Dorf', 'Ebmatingen, Leeacherstrasse', 'Ebmatingen, Looren', 'Erlenbach ZH', 'Erlenbach ZH (See)', 'Erlenbach ZH, Allmend', 'Erlenbach ZH, Alterswohnheim', 'Erlenbach ZH, Bahnhof', 'Erlenbach ZH, Bahnhofstrasse', 'Erlenbach ZH, Chapf', 'Erlenbach ZH, Erlen ...

# %%
start_node = {'src': 'Kilchberg',
              'dst': 'Wallisellen',
              'type': 'Zug',
              'line': 'S14',
              'departure_day': 'Monday',
              'departure_time': '0-19:39:00',
              'arrival_time': '0-20:29:00',
              'lateAvg': 0, 
              'lateStd': 0}

mid_node = {'src': 'Wallisellen',
              'dst': 'Urdorf',
              'type': 'Zug',
              'line': 'S8',
              'departure_day': 'Monday',
              'departure_time': '0-20:07:00',
              'arrival_time': '0-20:29:00',
              'lateAvg': 0, 
              'lateStd': 0}

end_node = {'src': 'Urdorf',
              'dst': 'Urdorf, Schlierenstrasse',
              'type': 'walk',
              'line': 'walk',
              'departure_day': 'null',
              'departure_time': 'null',
              'arrival_time': 'null',
              'lateAvg': 626.844, 
              'lateStd': 0}



trip = [start_node, mid_node,end_node]

# %%
node = start_node

src_station = stations.loc[node['src']]

src_station.name
# Out:
# 'Kilchberg'

# %%
def get_map_with_plot(trip):
    m = zurich_map = folium.Map(location=[47.376846, 8.543938],
     zoom_control = False, min_zoom=11, max_zoom=11, zoom_start=11,
      tiles="cartodbpositron", width='75%', height='75%')

    for idx, node in enumerate(trip):
        src_station = stations.loc[node['src']]
        src_pos = (src_station['Latitude'], src_station['Longitude'])
        dst_station = stations.loc[node['dst']]
        dst_pos = (dst_station['Latitude'], dst_station['Longitude']) 

        if idx == 0:
            # Start station
            folium.vector_layers.Marker(src_pos, popup=, tooltip=src_station.name).add_to(m)
        else:
            folium.vector_layers.Marker(src_pos, popup=None, tooltip=src_station.name).add_to(m)

        folium.PolyLine([src_pos, dst_pos], color="red", weight=2.5, opacity=1).add_to(m)

        if idx == (len(trip) - 1):
            # Plot arrival point
            folium.vector_layers.Marker(dst_pos, popup=None, tooltip=dst_station.name, icon=folium.Icon(color='red')).add_to(m)

    return m

# %%
get_map_with_plot(trip)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
zurich_map.save('zurich_map_blank.html')
